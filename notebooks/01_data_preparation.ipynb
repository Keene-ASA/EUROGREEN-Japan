# %% [markdown]
# # 01. Data Preparation for EUROGREEN-Japan Model
#
# **Objective**: Load, validate, and prepare the master dataset
#
# **Dataset**: 1994-2023 (30 years, 91 variables)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

print('Libraries loaded')

# %%
# Load data
df = pd.read_csv('../data/raw/df_eurogreen_japan_complete.csv')
print(f'Dataset: {df.shape}')
df.head()
